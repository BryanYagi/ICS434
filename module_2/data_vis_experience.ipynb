# %% [markdown]
# #### 1. Reproducing a plot
# 1. Use `numpy`'s `random` module to generate a random list of size 1000 of the following three categories: "CS", "Engineering", "Math" and "Physics"
#   1.1 Use a seed of 42
# 2. Store the data in an array called my `students_affiliations`
# 3. use `matplotlib` to plot the data in `students_affiliations` to reproduce the following graph
#  3.1 The plot uses "#FF5733" as color with an alpha (transparency) of 0.55.
#
# * Your graph should look exactly like the one below
#
# ![](https://www.dropbox.com/s/ffmu62es6d7evh5/experience_fig.png?dl=1)

# %% [markdown]
# #### 2. Generating a scatter plot
# * Generate random data to produce a scatter plot
#   * You can use any function to generate the data
#   * Instead of using circles as symbols, you should use squares.

# %%
import numpy as np

# %%
np.random.seed(42)
student_affiliations=np.random.choice(a=["CS","Engineering","Math","Physics"], size = 1000)
student_affiliations
# Out:
# array(['Math', 'Physics', 'CS', 'Math', 'Math', 'Physics', 'CS', 'CS',
#        'Math', 'Engineering', 'Math', 'Math', 'Math', 'Math', 'Physics',
#        'CS', 'Physics', 'Physics', 'Physics', 'Math', 'Engineering', 'CS',
#        'Engineering', 'Physics', 'Physics', 'Engineering', 'Engineering',
#        'Engineering', 'Physics', 'Physics', 'CS', 'CS', 'Physics',
#        'Engineering', 'Engineering', 'CS', 'Physics', 'CS', 'CS', 'Math',
#        'Math', 'Math', 'Engineering', 'Physics', 'Physics', 'Physics',
#        'Physics', 'Math', 'Engineering', 'Engineering', 'Math',
#        'Engineering', 'Math', 'Physics', 'Math', 'Physics', 'Physics',
#        'CS', 'Math', 'CS', 'Math', 'Math', 'CS', 'CS', 'Math',
#        'Engineering', 'Physics', 'CS', 'Physics', 'Engineering',
#        'Engineering', 'Engineering', 'CS', 'Engineering', 'CS',
#        'Engineering', 'Physics', 'Physics', 'Math', 'Physics', 'Math',
#        'Physics', 'CS', 'Physics', 'Math', 'Math', 'Engineering', 'CS',
#        'Physics', 'Engineering', 'Physics', 'Physics', 'Engineering',
#        'Engineering', 'Engineering', 'Engineering', 'Engineering',
#        'Physics', 'Engineering', 'CS', 'Math', 'Engineering',
#        'Engineering', 'Physics', 'Engineering', 'Engineering',
#        'Engineering', 'Physics', 'Engineering', 'Math', 'Physics', 'Math',
#        'Physics', 'Engineering', 'Math', 'Physics', 'CS', 'Engineering',
#        'Physics', 'CS', 'Physics', 'CS', 'Engineering', 'Math', 'CS',
#        'Physics', 'Engineering', 'CS', 'Physics', 'Physics', 'Physics',
#        'CS', 'CS', 'CS', 'Math', 'CS', 'CS', 'CS', 'Math', 'CS',
#        'Physics', 'CS', 'Physics', 'Physics', 'Physics', 'Math', 'Math',
#        'Math', 'CS', 'Physics', 'Math', 'Math', 'CS', 'Math', 'CS',
#        'Engineering', 'Math', 'Engineering', 'CS', 'Physics', 'Math',
#        'CS', 'Physics', 'Physics', 'Engineering', 'CS', 'Physics', 'Math',
#        'Math', 'Engineering', 'Physics', 'CS', 'Math', 'Physics',
#        'Physics', 'Engineering', 'Math', 'Math', 'CS', 'Math', 'CS',
#        'Math', 'Engineering', 'Math', 'CS', 'CS', 'Engineering', 'Math',
#        'Math', 'Engineering', 'Math', 'Math', 'CS', 'Math', 'Math',
#        'Engineering', 'Engineering', 'Physics', 'CS', 'Math', 'Math',
#        'Physics', 'Math', 'CS', 'Physics', 'CS', 'Physics', 'Physics',
#        'Engineering', 'CS', 'Math', 'Math', 'CS', 'Math', 'Math', 'CS',
#        'Physics', 'CS', 'Physics', 'Math', 'Math', 'Math', 'Engineering',
#        'Physics', 'Engineering', 'Engineering', 'CS', 'Engineering', 'CS',
#        'CS', 'Engineering', 'Physics', 'Physics', 'Physics', 'Physics',
#        'Physics', 'Engineering', 'Engineering', 'Math', 'Physics',
#        'Engineering', 'Math', 'Physics', 'CS', 'Math', 'Engineering',
#        'CS', 'CS', 'CS', 'Math', 'Engineering', 'CS', 'Physics', 'CS',
#        'CS', 'Math', 'Math', 'Engineering', 'Physics', 'Math', 'CS',
#        'Engineering', 'CS', 'CS', 'Math', 'Engineering', 'Physics',
#        'Physics', 'Math', 'Math', 'Engineering', 'Physics', 'Physics',
#        'Physics', 'CS', 'Physics', 'CS', 'Engineering', 'CS',
#        'Engineering', 'Physics', 'Physics', 'Engineering', 'Math',
#        'Engineering', 'Math', 'CS', 'CS', 'CS', 'Physics', 'CS', 'Math',
#        'CS', 'Engineering', 'Engineering', 'Physics', 'Engineering',
#        'Math', 'CS', 'Physics', 'CS', 'CS', 'Math', 'Engineering',
#        'Engineering', 'CS', 'Physics', 'Engineering', 'Physics',
#        'Engineering', 'Physics', 'Math', 'Physics', 'Math', 'Math',
#        'Physics', 'Math', 'CS', 'Math', 'Engineering', 'Physics', 'CS',
#        'Physics', 'Engineering', 'Engineering', 'Engineering', 'Math',
#        'Math', 'Physics', 'Physics', 'CS', 'CS', 'Physics', 'Math',
#        'Engineering', 'Physics', 'CS', 'Math', 'Physics', 'Physics',
#        'Math', 'Physics', 'Math', 'Engineering', 'Math', 'Math', 'Math',
#        'Physics', 'Physics', 'Math', 'Physics', 'CS', 'CS', 'Physics',
#        'Physics', 'Math', 'Engineering', 'Physics', 'CS', 'Math',
#        'Physics', 'CS', 'CS', 'Engineering', 'Math', 'Math',
#        'Engineering', 'Engineering', 'Math', 'Math', 'Physics', 'Physics',
#        'Engineering', 'Physics', 'CS', 'Physics', 'Physics', 'CS',
#        'Engineering', 'CS', 'Physics', 'Engineering', 'Physics', 'CS',
#        'CS', 'Physics', 'Math', 'Math', 'CS', 'CS', 'Math', 'Math',
#        'Physics', 'Physics', 'Math', 'Physics', 'Physics', 'Engineering',
#        'Physics', 'CS', 'Physics', 'Physics', 'Math', 'CS', 'Physics',
#        'Physics', 'Engineering', 'Physics', 'Physics', 'Engineering',
#        'Math', 'Physics', 'Engineering', 'CS', 'Math', 'CS', 'CS',
#        'Engineering', 'Physics', 'Engineering', 'Engineering',
#        'Engineering', 'Engineering', 'Math', 'Physics', 'CS', 'CS',
#        'Physics', 'CS', 'Physics', 'CS', 'Engineering', 'CS', 'Physics',
#        'Physics', 'Physics', 'Physics', 'Physics', 'Math', 'Math', 'CS',
#        'Physics', 'CS', 'Physics', 'Physics', 'Math', 'Math',
#        'Engineering', 'Math', 'Engineering', 'Engineering', 'Engineering',
#        'Engineering', 'Engineering', 'CS', 'Math', 'Engineering',
#        'Physics', 'Math', 'Math', 'Engineering', 'CS', 'Engineering',
#        'CS', 'Physics', 'Math', 'Physics', 'CS', 'CS', 'Physics', 'CS',
#        'Physics', 'Math', 'Physics', 'Math', 'Physics', 'CS', 'Physics',
#        'CS', 'Physics', 'Physics', 'Engineering', 'CS', 'Engineering',
#        'CS', 'Engineering', 'Math', 'Physics', 'CS', 'CS', 'Physics',
#        'CS', 'CS', 'Engineering', 'CS', 'Math', 'Math', 'Physics', 'CS',
#        'Physics', 'Math', 'CS', 'CS', 'Physics', 'Math', 'CS', 'Physics',
#        'Math', 'Physics', 'Engineering', 'CS', 'Engineering', 'Math',
#        'Engineering', 'Engineering', 'Math', 'Physics', 'Engineering',
#        'Physics', 'Engineering', 'Physics', 'Math', 'Engineering', 'Math',
#        'Engineering', 'Math', 'Math', 'Engineering', 'Engineering',
#        'Engineering', 'CS', 'Physics', 'CS', 'CS', 'Math', 'Engineering',
#        'Physics', 'Math', 'CS', 'Engineering', 'Math', 'Engineering',
#        'Math', 'Engineering', 'CS', 'Physics', 'CS', 'Physics',
#        'Engineering', 'Math', 'CS', 'Physics', 'CS', 'Physics', 'CS',
#        'Physics', 'Physics', 'Engineering', 'Physics', 'Engineering',
#        'Physics', 'Math', 'Math', 'Math', 'Physics', 'Engineering',
#        'Engineering', 'Physics', 'Math', 'Math', 'Engineering', 'Math',
#        'CS', 'Engineering', 'Math', 'Engineering', 'CS', 'Engineering',
#        'Engineering', 'Engineering', 'Engineering', 'CS', 'Physics',
#        'Engineering', 'Engineering', 'Math', 'Engineering', 'Math',
#        'Physics', 'CS', 'CS', 'Physics', 'CS', 'Physics', 'Physics',
#        'Physics', 'CS', 'Math', 'Physics', 'Engineering', 'CS', 'Physics',
#        'Physics', 'Engineering', 'Math', 'Math', 'Math', 'Physics',
#        'Physics', 'Physics', 'CS', 'Engineering', 'Physics',
#        'Engineering', 'Engineering', 'Math', 'CS', 'Physics', 'Math',
#        'Math', 'Physics', 'Engineering', 'Math', 'Engineering', 'CS',
#        'Engineering', 'CS', 'Engineering', 'Math', 'Math', 'CS',
#        'Physics', 'CS', 'CS', 'Engineering', 'Engineering', 'CS', 'Math',
#        'Engineering', 'Physics', 'Engineering', 'Engineering', 'Physics',
#        'CS', 'Physics', 'CS', 'CS', 'CS', 'Physics', 'CS', 'Math',
#        'Physics', 'Math', 'CS', 'Engineering', 'CS', 'Math', 'Math',
#        'Physics', 'Engineering', 'Physics', 'Math', 'CS', 'Engineering',
#        'CS', 'CS', 'Engineering', 'Physics', 'CS', 'Math', 'CS',
#        'Engineering', 'Engineering', 'Engineering', 'Physics', 'CS',
#        'Physics', 'Physics', 'Engineering', 'Engineering', 'Physics',
#        'CS', 'Math', 'Physics', 'CS', 'Engineering', 'Engineering', 'CS',
#        'Math', 'Engineering', 'Engineering', 'Engineering', 'CS',
#        'Physics', 'Engineering', 'Physics', 'Math', 'Engineering',
#        'Engineering', 'Math', 'Engineering', 'Physics', 'CS', 'Physics',
#        'CS', 'CS', 'Physics', 'Physics', 'Physics', 'Physics', 'Math',
#        'Engineering', 'CS', 'Physics', 'Physics', 'Physics', 'Math',
#        'Physics', 'Physics', 'Physics', 'Engineering', 'Math', 'Physics',
#        'CS', 'CS', 'CS', 'Math', 'Math', 'CS', 'Physics', 'Math', 'CS',
#        'CS', 'Physics', 'Engineering', 'Math', 'Physics', 'CS', 'CS',
#        'Physics', 'Math', 'Engineering', 'Engineering', 'CS', 'Math',
#        'Engineering', 'Math', 'Math', 'CS', 'Engineering', 'Physics',
#        'CS', 'Engineering', 'Engineering', 'Engineering', 'Engineering',
#        'Engineering', 'Math', 'CS', 'Math', 'Physics', 'Engineering',
#        'CS', 'Engineering', 'CS', 'Math', 'CS', 'Physics', 'Physics',
#        'CS', 'CS', 'CS', 'CS', 'Physics', 'Engineering', 'CS', 'CS',
#        'Physics', 'Physics', 'Math', 'CS', 'Math', 'Physics', 'Physics',
#        'Engineering', 'CS', 'Math', 'Physics', 'Physics', 'Math',
#        'Engineering', 'Physics', 'CS', 'Physics', 'CS', 'Math', 'CS',
#        'Math', 'CS', 'Math', 'CS', 'Engineering', 'CS', 'CS',
#        'Engineering', 'Physics', 'Physics', 'CS', 'Engineering', 'CS',
#        'Math', 'Math', 'CS', 'Physics', 'Physics', 'CS', 'CS', 'Math',
#        'Physics', 'CS', 'Math', 'Physics', 'Engineering', 'Math',
#        'Physics', 'Physics', 'Math', 'Engineering', 'Math', 'Physics',
#        'CS', 'CS', 'Math', 'Physics', 'CS', 'Physics', 'Math', 'CS',
#        'Physics', 'CS', 'Math', 'Physics', 'CS', 'Math', 'CS', 'CS',
#        'Engineering', 'Engineering', 'Math', 'Engineering', 'Math',
#        'Engineering', 'CS', 'Math', 'Math', 'CS', 'Math', 'Math',
#        'Engineering', 'Math', 'Physics', 'CS', 'Engineering',
#        'Engineering', 'Physics', 'CS', 'CS', 'Engineering', 'Math',
#        'Engineering', 'CS', 'Physics', 'Engineering', 'CS', 'Engineering',
#        'Math', 'Engineering', 'Engineering', 'CS', 'CS', 'CS',
#        'Engineering', 'Math', 'Physics', 'Physics', 'CS', 'CS',
#        'Engineering', 'Physics', 'CS', 'Math', 'Math', 'CS', 'CS',
#        'Physics', 'Physics', 'Engineering', 'Physics', 'Math', 'Math',
#        'CS', 'Physics', 'Engineering', 'Math', 'Math', 'Engineering',
#        'Engineering', 'Math', 'Math', 'Engineering', 'Math', 'CS', 'CS',
#        'Engineering', 'Physics', 'Engineering', 'Engineering', 'Physics',
#        'Physics', 'Physics', 'CS', 'Math', 'CS', 'Math', 'CS', 'Math',
#        'CS', 'Physics', 'Engineering', 'CS', 'Math', 'Physics', 'CS',
#        'CS', 'Physics', 'CS', 'Engineering', 'CS', 'Engineering',
#        'Engineering', 'Physics', 'CS', 'Physics', 'CS', 'CS', 'Math',
#        'CS', 'Physics', 'Engineering', 'CS', 'Math', 'Physics', 'CS',
#        'Physics', 'Math', 'Math', 'Physics', 'CS', 'Engineering', 'Math',
#        'CS', 'CS', 'Engineering', 'Math', 'Math', 'CS', 'CS',
#        'Engineering', 'Engineering', 'Math', 'Physics', 'Math', 'CS',
#        'Math', 'Physics', 'Engineering', 'Physics', 'Physics', 'Physics',
#        'Engineering', 'Physics', 'Physics', 'Physics', 'CS', 'Physics',
#        'Engineering', 'Physics', 'Physics', 'Engineering', 'Physics',
#        'Engineering', 'Physics', 'Engineering', 'Physics', 'Physics',
#        'CS', 'CS', 'Physics', 'Physics', 'Math'], dtype='<U11')
